# %%
import pandas as pd

# %%
# cite_seq = pd.read_hdf('./data/EDA/test_cite_inputs.h5')
cite_seq = pd.read_hdf('./data/EDA/train_cite_inputs.h5')
cite_seq.head()
# Out:
# gene_id       ENSG00000121410_A1BG  ENSG00000268895_A1BG-AS1  \
# cell_id
# 45006fe3e4c8                   0.0                       0.0
# d02759a80ba2                   0.0                       0.0
# c016c6b0efa5                   0.0                       0.0
# ba7f733a4f75                   0.0                       0.0
# fbcf2443ffb2                   0.0                       0.0
#
# gene_id       ENSG00000175899_A2M  ENSG00000245105_A2M-AS1  \
# cell_id
# 45006fe3e4c8                  0.0                      0.0
# d02759a80ba2                  0.0                      0.0
# c016c6b0efa5                  0.0                      0.0
# ba7f733a4f75                  0.0                      0.0
# fbcf2443ffb2                  0.0                      0.0
#
# gene_id       ENSG00000166535_A2ML1  ENSG00000128274_A4GALT  \
# cell_id
# 45006fe3e4c8                    0.0                0.000000
# d02759a80ba2                    0.0                0.000000
# ...

# %%
cite_seq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70988 entries, 45006fe3e4c8 to c91b6b2ccd3d
# Columns: 22050 entries, ENSG00000121410_A1BG to ENSG00000074755_ZZEF1
# dtypes: float32(22050)
# memory usage: 5.8+ GB

# %% [markdown]
# RNA library-size normalized* and log1p transformed* counts (gene expression levels), with 48,663 rows corresponding to cells and 22,050 columns corresponding to genes given by {gene_name}_{gene_ensemble-ids}.
#
# Library sized normalization: normalize so all cells have the same total gene count. TODO: understand cite-seq assay better.
#
# Some confusion about this in forums:
# - https://www.kaggle.com/competitions/open-problems-multimodal/discussion/346341

# %%
cite_seq.head().T.sum()
# Out:
# cell_id
# 45006fe3e4c8    18104.728516
# d02759a80ba2    17466.855469
# c016c6b0efa5    20732.220703
# ba7f733a4f75    25030.843750
# fbcf2443ffb2    25476.197266
# dtype: float32

# %%
cite_seq.describe()
# Out:
# gene_id  ENSG00000121410_A1BG  ENSG00000268895_A1BG-AS1  ENSG00000175899_A2M  \
# count            70988.000000              70988.000000         70988.000000
# mean                 0.086048                  0.199110             0.017556
# std                  0.564659                  0.843376             0.263296
# min                  0.000000                  0.000000             0.000000
# 25%                  0.000000                  0.000000             0.000000
# 50%                  0.000000                  0.000000             0.000000
# 75%                  0.000000                  0.000000             0.000000
# max                  5.402543                  5.697094             6.385898
#
# gene_id  ENSG00000245105_A2M-AS1  ENSG00000166535_A2ML1  \
# count               70988.000000           70988.000000
# mean                    0.167338               0.001346
# std                     0.783140               0.071854
# ...

# %%
# across genes, expression is usually low across cells
cite_seq.describe().T.mean()
# Out:
# count    70988.000000
# mean         0.977238
# std          0.995665
# min          0.015569
# 25%          0.393084
# 50%          0.769719
# 75%          1.404981
# max          5.533523
# dtype: float64

# %%
cite_seq_prot = pd.read_hdf('./data/EDA/train_cite_targets.h5')
cite_seq_prot.head()
# Out:
# gene_id           CD86     CD274     CD270     CD155     CD112      CD47  \
# cell_id
# 45006fe3e4c8  1.167804  0.622530  0.106959  0.324989  3.331674  6.426002
# d02759a80ba2  0.818970  0.506009  1.078682  6.848758  3.524885  5.279456
# c016c6b0efa5 -0.356703 -0.422261 -0.824493  1.137495  0.518924  7.221962
# ba7f733a4f75 -1.201507  0.149115  2.022468  6.021595  7.258670  2.792436
# fbcf2443ffb2 -0.100404  0.697461  0.625836 -0.298404  1.369898  3.254521
#
# gene_id            CD48      CD40     CD154      CD52  ...      CD94  \
# cell_id                                                ...
# 45006fe3e4c8   1.480766 -0.728392 -0.468851 -0.073285  ... -0.448390
# d02759a80ba2   4.930438  2.069372  0.333652 -0.468088  ...  0.323613
# c016c6b0efa5  -0.375034  1.738071  0.142919 -0.971460  ...  1.348692
# ba7f733a4f75  21.708519 -0.137913  1.649969 -0.754680  ...  1.504426
# fbcf2443ffb2  -1.659380  0.643531  0.902710  1.291877  ...  0.777023
#
# ...

# %%
cite_seq_prot.describe()
# Out:
# gene_id          CD86         CD274         CD270         CD155         CD112  \
# count    70988.000000  70988.000000  70988.000000  70988.000000  70988.000000
# mean         0.454768      0.466369      0.918049      5.610967      5.307707
# std          1.393927      0.894457      0.923267      2.542798      2.043094
# min         -5.717155     -5.292869     -4.187119     -3.907870     -3.107560
# 25%         -0.366943     -0.144443      0.289499      3.830644      3.961191
# 50%         -0.031319      0.416705      0.892687      5.395159      5.324531
# 75%          1.050250      1.014566      1.519067      7.176124      6.682766
# max         37.034649      8.832175      6.191772     18.115868     14.311632
#
# gene_id          CD47          CD48          CD40         CD154          CD52  \
# count    70988.000000  70988.000000  70988.000000  70988.000000  70988.000000
# mean         7.447880      4.052779      0.399293      0.714440      0.840576
# ...

# %%
cite_seq_prot.describe().T.mean()
# Out:
# count    70988.000000
# mean         1.886106
# std          1.759287
# min         -6.544227
# 25%          0.696609
# 50%          1.616853
# 75%          2.791192
# max         21.659718
# dtype: float64
